# %% [markdown]
# # <center> Actividades de IA</center>
# ## <center> NOMBRE: Gemberth Josue Delgado Delgado</center>
# ## <center>CURSO: 8to "A"</center>
# ## <center>ASIGNATURA: INteligencia Artificial</center>
# ## <center>DOCENTE: Ing. Santana Cedeño Hiraida</center>

# %% [markdown]
# ### ACTIVIDAD 1. CREAR UN ARREGLO DE 4 DIMENSIONES ORDENADOS POR LA EDAD O NOMBRE.

# %%
import numpy as np
key= [('Nombre','S10'),('Apellido','S10'),('Edad',int)]
valor=[('Gemberth','Delgado',21),('Allison','Delgado',11),('Adriana','Delgado',39),('Romulo','Delgado',65)]
arr= np.array(valor, dtype=key)
print(arr)
# Out:
# [(b'Gemberth', b'Delgado', 21) (b'Allison', b'Delgado', 11)
#  (b'Adriana', b'Delgado', 39) (b'Romulo', b'Delgado', 65)]

# %%
print("Ordenar por nombre")
np.sort(arr,order='Nombre')
# Out:
# Ordenar por nombre
# array([(b'Adriana', b'Delgado', 39), (b'Allison', b'Delgado', 11),
#        (b'Gemberth', b'Delgado', 21), (b'Romulo', b'Delgado', 65)],
#       dtype=[('Nombre', 'S10'), ('Apellido', 'S10'), ('Edad', '<i4')])

# %%
print("Ordenar por edad")
np.sort(arr,order='Edad')
# Out:
# Ordenar por edad
# array([(b'Allison', b'Delgado', 11), (b'Gemberth', b'Delgado', 21),
#        (b'Adriana', b'Delgado', 39), (b'Romulo', b'Delgado', 65)],
#       dtype=[('Nombre', 'S10'), ('Apellido', 'S10'), ('Edad', '<i4')])

# %% [markdown]
# ### ACTIVIDAD 2.
#
# CON LOS DATOS DE CANCIONES.
# ELIJA LAS 3 COLUMNAS QUE USTED DESEE Y ORDENELAS ASCENDENTEMENTE

# %%
import pandas as pd
datos = pd.read_csv('musica.csv')
datos
# Out:
#                        id                               name       artists  \
# 0   6DCZcSspjsKoFjzjrWoCd                         God's Plan       Santana
# 1   3ee8Jmje8o58CHK66QrVC                               SAD!  XXXTENTACION
# 2   0e7ipj03S05BNilyu5bRz         rockstar (feat. 21 Savage)   Post Malone
# 3   3swc6WTsr7rl9DqQKQA55       Psycho (feat. Ty Dolla $ign)   Post Malone
# 4   2G7V7zsVDxg1yRsu7Ew9R                     In My Feelings         Drake
# ..                    ...                                ...           ...
# 95  630sXRhIcfwr2e4RdNtjK                  Rewrite The Stars     Zac Efron
# 96  2xmrfQpmS2iJExTlklLoA  I Miss You (feat. Julia Michaels)  Clean Bandit
# 97  5WvAo7DNuPRmk4APhdPzi                         No Brainer     DJ Khaled
# 98  1j4kHkkpqZRBwE0A4CN4Y        Dusk Till Dawn - Radio Edit          ZAYN
# 99  3EPXxR3ImUwfayaurPi3c                         Be Alright    Dean Lewis
#
# ...

# %%
data = (datos[['name','artists','energy']])
print('Ordenado por artista')
data.sort_values(by= ['artists'],ascending = True)
# Out:
# Ordenado por artista
#                                       name              artists  energy
# 23                              Youngblood  5 Seconds of Summer   0.854
# 55  FEFE (feat. Nicki Minaj & Murda Beatz)              6ix9ine   0.387
# 88                                Downtown               Anitta   0.679
# 60                                    2002           Anne-Marie   0.683
# 65                          God is a woman        Ariana Grande   0.658
# ..                                     ...                  ...     ...
# 35         Eastside (with Halsey & Khalid)         benny blanco   0.680
# 20                                     NaN                  NaN     NaN
# 69                                     NaN                  NaN     NaN
# 70                                     NaN                  NaN     NaN
# 77                                     NaN                  NaN     NaN
#
# [100 rows x 3 columns]

# %%
print('Ordenado por energia')
data.sort_values(by= ['energy'],ascending = True)
# Out:
# Ordenado por energia
#                                    name        artists  energy
# 80                 lovely (with Khalid)  Billie Eilish   0.296
# 84  Perfect Duet (Ed Sheeran & Beyonc?)     Ed Sheeran   0.299
# 38                              changes   XXXTENTACION   0.308
# 91                           Yes Indeed       Lil Baby   0.346
# 52                 Too Good At Goodbyes      Sam Smith   0.375
# ..                                  ...            ...     ...
# 12                        Nice For What          Drake   0.909
# 20                                  NaN            NaN     NaN
# 69                                  NaN            NaN     NaN
# 70                                  NaN            NaN     NaN
# 77                                  NaN            NaN     NaN
#
# [100 rows x 3 columns]

# %% [markdown]
# # ACTIVIDAD 3.
# Con estos datos que ya tienes agrega una nueva columna para que puedas predecir, en esa columna ahora vas a tener el país del programador. Ojo, recuerda que la regresión lineal simple solo trabaja con datos continuos, así que cada país deberás represarlo con un número, por ejemplo Ecuador = 1, España = 2.

# %%
pd.options.mode.chained_assignment = None 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
dataset = pd.read_csv('salarios_1.csv')
dataset.head (5)
# Out:
#    Aexperiencia  Salario
# 0          10.0    42500
# 1           8.0    36302
# 2           5.4    35000
# 3           2.5    18103
# 4           1.0    15000

# %%
dataset['pais']=np.random.randint(1, 7,dataset.shape[0])
for i in dataset.index:
    if dataset['Salario'][i] >= 15000 and dataset['Salario'][i] < 20000:
        dataset['pais'][i] = 1 
    elif dataset['Salario'][i] >= 20000 and dataset['Salario'][i] < 25000:
        dataset['pais'][i] = 2
    elif dataset['Salario'][i] >= 25000 and dataset['Salario'][i] < 30000:
        dataset['pais'][i] = 3
    elif dataset['Salario'][i] >= 30000 and dataset['Salario'][i] < 35000:
        dataset['pais'][i] = 4
    else:
        dataset['pais'][i] = 5

dataset
#print(dataset.head(5))
# Out:
#     Aexperiencia  Salario  pais
# 0           10.0    42500     5
# 1            8.0    36302     5
# 2            5.4    35000     5
# 3            2.5    18103     1
# 4            1.0    15000     1
# 5            8.0    37000     5
# 6            4.0    26300     3
# 7            6.0    35201     5
# 8            2.0    18302     1
# 9           10.0    42000     5
# 10           4.0    27000     3
# 11           7.0    35201     5
# 12           3.0    19201     1
# 13           5.0    28000     3
# 14           2.0    17000     1
# 15           5.0    33402     4
# 16           3.0    19000     1
# 17           2.0    18200     1
# 18           3.0    19000     1
# 19           2.0    17301     1
# 20           5.0    28000     3
# 21           3.4    20000     2
# 22           5.3    27900     3
# 23           2.1    17500     1
# 24           9.2    40000     5
# 25          10.0    42500     5
# 26           3.2    18300     1
# 27          10.0    40000     5
# ...

# %%
x=dataset.iloc[:, 2:3].values
y=dataset.iloc[:, 1].values

# %%
X_train,X_test,Y_train,Y_test= train_test_split(x,y,test_size=0.2,random_state=0)
X_train
# Out:
# array([[5],
#        [5],
#        [1],
#        [3],
#        [5],
#        [1],
#        [1],
#        [1],
#        [1],
#        [3],
#        [5],
#        [1],
#        [3],
#        [1],
#        [1],
#        [1],
#        [5],
#        [5],
#        [5],
#        [1],
#        [5],
#        [2],
#        [4],
#        [1]])

# %%
regresion= LinearRegression()
regresion.fit(X_train, Y_train)
vision_train= plt
vision_train.scatter(X_train, Y_train, color ='green')
vision_train.plot(X_train, regresion.predict(X_train), color='black')
vision_train.title('Salario VS país (Entrenamiento)')
vision_train.xlabel('País')
vision_train.ylabel('Salario')
vision_train.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
vision_train.scatter(X_test, Y_test, color ='red')
vision_train.plot(X_train, regresion.predict(X_train), color='black')
vision_train.title('Salario VS país')
vision_train.xlabel('País')
vision_train.ylabel('Salario')
vision_train.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
regresion.score(X_test, Y_test)
# Out:
# 0.9109806621837582
